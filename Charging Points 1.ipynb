# %%
import folium
from folium import plugins
import ipywidgets
import geocoder
import geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds
import numpy as np 
import matplotlib.pyplot as plt

df = pd.read_excel('IMKL-Appurtenance_E_Lv_Charging_Point_Noord_ligging.xlsx')

# %%
#Going to clean one data set and try to plot it on a map in this case North side. To see where enexis has this charging points.
df
# Out:
#      IMKL-Appurtenance_E_Lv_Charging_Point_Noord_ligging           Unnamed: 1  \
# 0                                                   WKT            BEGINLIFES
# 1             POINT (52.2651186077053 6.14438488438369)   2021-04-21 00:00:00
# 2             POINT (52.2651902966879 6.22067538822017)   2021-04-21 00:00:00
# 3             POINT (52.2182735266067 6.96757726132068)   2021-04-14 00:00:00
# 4             POINT (52.2505848146862 6.14107293781506)   2021-04-21 00:00:00
# ...                                                 ...                   ...
# 1198          POINT (52.8068852122338 7.02961511111643)   2021-01-27 00:00:00
# 1199          POINT (52.2557620799322 6.15083579896986)   2021-03-22 00:00:00
# 1200          POINT (52.7408667659103 6.08167634040964)   2021-03-18 00:00:00
# 1201          POINT (52.5329935943936 6.10156503455245)   2021-03-18 00:00:00
# 1202          POINT (53.0677710385639 6.43993604070644)   2021-01-19 00:00:00
#
# ...

# %%
#I will put a new name to columns I want use 
df.rename({'IMKL-Appurtenance_E_Lv_Charging_Point_Noord_ligging' : 'Location(WKT)',
          'Unnamed: 1': 'START LIFE',
          'Unnamed: 2': 'SOURCE',
          'Unnamed: 3': 'NETWORK',
          'Unnamed: 4': 'CURRENT',
          'Unnamed: 5': 'VALIDFROM',
          'Unnamed: 6': 'VERTICALPO', 
          'Unnamed: 7': 'APPURTENAN',
          'Unnamed: 8': 'LABEL',
          'Unnamed: 9': 'DESCRIPTION',
          'Unnamed: 10': 'TOP GROUND', 
          'Unnamed: 11': 'GEONAUWKEU',
          'Unnamed: 12': 'ROTATIEHOE',
          'Unnamed: 13': 'ROTATIE_01'}, axis = 'columns', inplace= True )

# %%
df
# Out:
#                                   Location(WKT)           START LIFE  \
# 0                                           WKT           BEGINLIFES
# 1     POINT (52.2651186077053 6.14438488438369)  2021-04-21 00:00:00
# 2     POINT (52.2651902966879 6.22067538822017)  2021-04-21 00:00:00
# 3     POINT (52.2182735266067 6.96757726132068)  2021-04-14 00:00:00
# 4     POINT (52.2505848146862 6.14107293781506)  2021-04-21 00:00:00
# ...                                         ...                  ...
# 1198  POINT (52.8068852122338 7.02961511111643)  2021-01-27 00:00:00
# 1199  POINT (52.2557620799322 6.15083579896986)  2021-03-22 00:00:00
# 1200  POINT (52.7408667659103 6.08167634040964)  2021-03-18 00:00:00
# 1201  POINT (52.5329935943936 6.10156503455245)  2021-03-18 00:00:00
# 1202  POINT (53.0677710385639 6.43993604070644)  2021-01-19 00:00:00
#
#                                              SOURCE       NETWORK     CURRENT  \
# ...

# %%
df.drop('LABEL', axis = 'columns', inplace=True)
df.drop(0 , axis = 'rows', inplace=True)

# %%
df
# Out:
#                                   Location(WKT)           START LIFE  \
# 1     POINT (52.2651186077053 6.14438488438369)  2021-04-21 00:00:00
# 2     POINT (52.2651902966879 6.22067538822017)  2021-04-21 00:00:00
# 3     POINT (52.2182735266067 6.96757726132068)  2021-04-14 00:00:00
# 4     POINT (52.2505848146862 6.14107293781506)  2021-04-21 00:00:00
# 5      POINT (52.262815875494 6.16550997857659)  2021-04-21 00:00:00
# ...                                         ...                  ...
# 1198  POINT (52.8068852122338 7.02961511111643)  2021-01-27 00:00:00
# 1199  POINT (52.2557620799322 6.15083579896986)  2021-03-22 00:00:00
# 1200  POINT (52.7408667659103 6.08167634040964)  2021-03-18 00:00:00
# 1201  POINT (52.5329935943936 6.10156503455245)  2021-03-18 00:00:00
# 1202  POINT (53.0677710385639 6.43993604070644)  2021-01-19 00:00:00
#
#                                              SOURCE       NETWORK     CURRENT  \
# ...

# %%
df.drop('CURRENT', axis = 'columns', inplace=True )
df.drop('VERTICALPO', axis = 'columns', inplace=True )
df.drop('APPURTENAN' , axis = 'columns', inplace=True )
df.drop('DESCRIPTION' , axis = 'columns', inplace=True )
df.drop('TOP GROUND' , axis = 'columns', inplace=True )
df.drop('GEONAUWKEU' , axis = 'columns', inplace=True )
df.drop('ROTATIEHOE', axis = 'columns', inplace=True )
df.drop('ROTATIE_01', axis = 'columns', inplace=True )

# %%
df
# Out:
#                                   Location(WKT)           START LIFE  \
# 1     POINT (52.2651186077053 6.14438488438369)  2021-04-21 00:00:00
# 2     POINT (52.2651902966879 6.22067538822017)  2021-04-21 00:00:00
# 3     POINT (52.2182735266067 6.96757726132068)  2021-04-14 00:00:00
# 4     POINT (52.2505848146862 6.14107293781506)  2021-04-21 00:00:00
# 5      POINT (52.262815875494 6.16550997857659)  2021-04-21 00:00:00
# ...                                         ...                  ...
# 1198  POINT (52.8068852122338 7.02961511111643)  2021-01-27 00:00:00
# 1199  POINT (52.2557620799322 6.15083579896986)  2021-03-22 00:00:00
# 1200  POINT (52.7408667659103 6.08167634040964)  2021-03-18 00:00:00
# 1201  POINT (52.5329935943936 6.10156503455245)  2021-03-18 00:00:00
# 1202  POINT (53.0677710385639 6.43993604070644)  2021-01-19 00:00:00
#
#                                              SOURCE       NETWORK  \
# 1     !elec!e_lv_charging_point!9097473703459609049  laagspanning
# ...

# %%
#Now let's see where are these charging points and play around with folium 
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map1 = folium.Map(location=[52.1326, 5.2913], zoom_start=7, width=600, height=400, control_scale=True)

# %%
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#let's and some widgets and also let's make it interactive 

#Widget
select_widget=ipywidgets.Select(
    options= ['Open Street Map', 'Terrain', 'Toner', 'Watercolor', 'Positron', 'Dark Matter'], 
    value='Open Street Map',
    description='Map Type:',
    disabled=False)

#Widget Function 
def select (map_type):
    if map_type == 'Open Street Map':
        display(folium.Map(location=[52.1326, 5.2913], zoom_start=7, height=400 ))
    if map_type == 'Terrain':
            display(folium.Map(location=[52.1326, 5.2913], tiles= 'Stamen Terrain', zoom_start=7, height=400))
    if map_type == 'Toner':
        display(folium.Map(location=[52.1326, 5.2913], tiles='Stamen Toner', zoom_start=7, height=400))
    if map_type == 'Watercolor':
        display(folium.Map(location=[52.1326, 5.2913], tiles='Stamen Watercolor', zoom_start=7, height=400))
    if map_type == 'Positron':
        display(folium.Map(location=[52.1326, 5.2913], tiles='CartoDB Positron', zoom_start=7, height=400))
    if map_type == 'Dark Matter':
        display(folium.Map(location=[52.1326, 5.2913], tiles='CartoDB Dark_Matter', zoom_start=7, height=400))
        
        #Create interaction
        ipywidgets.interact(select, map_type = select_widget)

# %%
#let's and some widgets and also let's make it interactive 

#Widget
select_widget=ipywidgets.Select(
    options=['Open Street Map', 'Terrain', 'Toner', 'Watercolor', 'Positron', 'Dark Matter'],
    value='Open Street Map',
    description='Map Type:',
    disabled=False)

# widget function
def select(map_type):
    if map_type == 'Open Street Map':
        display(folium.Map(location=[52.1326, 5.2913], zoom_start=7, height=700))
    if map_type == 'Terrain':
        display(folium.Map(location=[52.1326, 5.2913], tiles='Stamen Terrain', zoom_start=7, height=400))
    if map_type == 'Toner':
        display(folium.Map(location=[52.1326, 5.2913], tiles='Stamen Toner', zoom_start=7, height=400))
    if map_type == 'Watercolor':
        display(folium.Map(location=[52.1326, 5.2913], tiles='Stamen Watercolor', zoom_start=7, height=400))
    if map_type == 'Positron':
        display(folium.Map(location=[52.1326, 5.2913], tiles='CartoDB Positron', zoom_start=7, height=400))
    if map_type == 'Dark Matter':
        display(folium.Map(location=[52.1326, 5.2913], tiles='CartoDB Dark_Matter', zoom_start=7, height=400))
        
# interaction between widgets and function    
ipywidgets.interact(select, map_type=select_widget)
# Out:
# interactive(children=(Select(description='Map Type:', options=('Open Street Map', 'Terrain', 'Toner', 'Waterco…
# <function __main__.select(map_type)>

# %%
#Let's add layer control to the map 
map_layer_control = folium.Map(location= [52, 5], zoom_start=7)

#add tiles to the map 

folium.raster_layers.TileLayer('Open Street Map').add_to(map_layer_control)
folium.raster_layers.TileLayer('Stamen Terrain').add_to(map_layer_control)
folium.raster_layers.TileLayer('Stamen Toner').add_to(map_layer_control)
folium.raster_layers.TileLayer('Stamen Watercolor').add_to(map_layer_control)
folium.raster_layers.TileLayer('CartoDB Positron').add_to(map_layer_control)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(map_layer_control)

folium.LayerControl().add_to(map_layer_control)

map_layer_control
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#Mini map fore easy location through the map
map_with_mini = folium.Map(location =[52, 5], zoom_start=7) 
minimap= plugins.MiniMap(toggle_display=True) 

#add minimap to map 
map_with_mini.add_child(minimap)

#Add scroll zoom feature the map 
plugins.ScrollZoomToggler().add_to(map_with_mini)

#Now let's add fullscreen button to the screen 
plugins.Fullscreen(position='topright').add_to(map_with_mini)

map_with_mini
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#Let's try to plot the charging points on the map 

#create map 
ch_ports = folium.Map(location=[52, 5], zoom_start=7)

#plot locations
for (index, row) in df.iterrows():
    folium.Marker(location=[row.loc['Location(WKT)']]).add_to(ch_ports)

ch_ports
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-f381bda04778> in <module>
#       6 #plot locations
#       7 for (index, row) in df.iterrows():
# ----> 8     folium.Marker(location=[row.loc['Location(WKT)']]).add_to(ch_ports)
#       9
#      10 ch_ports
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     275         super(Marker, self).__init__()
#     276         self._name = 'Marker'
# --> 277         self.location = validate_location(location) if location else None
#     278         self.options = parse_options(
#     279             draggable=draggable or None,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/utilities.py in validate_location(location)
#      48                         '{!r} of type {}.'.format(location, type(location)))
# ...

# %%
df
# Out:
#                                   Location(WKT)           START LIFE  \
# 1     POINT (52.2651186077053 6.14438488438369)  2021-04-21 00:00:00
# 2     POINT (52.2651902966879 6.22067538822017)  2021-04-21 00:00:00
# 3     POINT (52.2182735266067 6.96757726132068)  2021-04-14 00:00:00
# 4     POINT (52.2505848146862 6.14107293781506)  2021-04-21 00:00:00
# 5      POINT (52.262815875494 6.16550997857659)  2021-04-21 00:00:00
# ...                                         ...                  ...
# 1198  POINT (52.8068852122338 7.02961511111643)  2021-01-27 00:00:00
# 1199  POINT (52.2557620799322 6.15083579896986)  2021-03-22 00:00:00
# 1200  POINT (52.7408667659103 6.08167634040964)  2021-03-18 00:00:00
# 1201  POINT (52.5329935943936 6.10156503455245)  2021-03-18 00:00:00
# 1202  POINT (53.0677710385639 6.43993604070644)  2021-01-19 00:00:00
#
#                                              SOURCE       NETWORK  \
# 1     !elec!e_lv_charging_point!9097473703459609049  laagspanning
# ...

# %%
df['Location(WKT)'] = df['Location(WKT)'].str.strip('POINT(')
df['Latitude'] = df['Location(WKT)'].str[2:19]

# %%
df.head(50)
# Out:
#                            Location(WKT)           START LIFE  \
# 1    (52.2651186077053 6.14438488438369)  2021-04-21 00:00:00
# 2    (52.2651902966879 6.22067538822017)  2021-04-21 00:00:00
# 3    (52.2182735266067 6.96757726132068)  2021-04-14 00:00:00
# 4    (52.2505848146862 6.14107293781506)  2021-04-21 00:00:00
# 5     (52.262815875494 6.16550997857659)  2021-04-21 00:00:00
# 6    (53.0169343771055 6.58172056041808)  2021-04-21 00:00:00
# 7    (52.3047619200879 6.74887301052033)  2021-04-21 00:00:00
# 8    (52.2113698035522 6.88645448671808)  2021-04-21 00:00:00
# 9    (52.5377324292504 6.05236607018301)  2021-04-07 00:00:00
# 10   (53.3617289873374 6.52100892496009)  2021-04-08 00:00:00
# 11   (52.2475707547167 6.21025719010125)  2021-04-07 00:00:00
# 12   (53.1696624125698 6.25611038241235)  2021-04-08 00:00:00
# 13   (52.5020966623003 6.10802003970324)  2021-04-22 00:00:00
# 14   (52.4915409140685 6.11156089791444)  2021-04-21 00:00:00
# ...

# %%
df
